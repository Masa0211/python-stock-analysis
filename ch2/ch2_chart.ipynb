# %% [markdown]
# ### Get stock price from stooq

# %%
import pandas_datareader.data as pdr
name = "9434.JP"
df = pdr.DataReader(name, "stooq")
display(df)

df = df.sort_index()
display(df)

# df = df.sort_values("Close")
# display(df)
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2024-12-25   197.00   197.30   195.00   196.10  4.304850e+07
# 2024-12-24   197.90   198.40   197.20   197.30  3.466060e+07
# 2024-12-23   197.80   198.50   196.90   197.90  4.321400e+07
# 2024-12-20   197.00   198.30   196.30   196.60  7.237990e+07
# 2024-12-19   196.50   197.90   195.70   197.40  5.974130e+07
# ...             ...      ...      ...      ...           ...
# 2020-01-09  1225.26  1225.68  1217.75  1225.26  8.830074e+06
# 2020-01-08  1211.90  1213.99  1199.81  1208.57  1.091443e+07
# 2020-01-07  1211.08  1221.51  1211.08  1217.32  7.532280e+06
# 2020-01-06  1217.75  1221.09  1206.89  1208.57  9.771190e+06
# 2019-12-30  1212.34  1225.68  1211.08  1218.17  7.680246e+06
#
# [1218 rows x 5 columns]
#                Open     High      Low    Close        Volume
# Date
# 2019-12-30  1212.34  1225.68  1211.08  1218.17  7.680246e+06
# 2020-01-06  1217.75  1221.09  1206.89  1208.57  9.771190e+06
# ...

# %% [markdown]
# ### Plot the closing price
#
# There was a stock split at the end of September 2024

# %%
df_close = df['Close']
print(type(df_close))
display(df_close)
df_close.plot()
# Out:
# <class 'pandas.core.series.Series'>
# Date
# 2019-12-30    1218.17
# 2020-01-06    1208.57
# 2020-01-07    1217.32
# 2020-01-08    1208.57
# 2020-01-09    1225.26
#                ...
# 2024-12-19     197.40
# 2024-12-20     196.60
# 2024-12-23     197.90
# 2024-12-24     197.30
# 2024-12-25     196.10
# Name: Close, Length: 1218, dtype: float64
# <Axes: xlabel='Date'>

# %%
df.tail(10)
# Out:
#              Open   High    Low  Close      Volume
# Date
# 2024-12-12  200.6  202.0  200.3  201.4  52857500.0
# 2024-12-13  197.0  200.3  196.8  199.7  60809600.0
# 2024-12-16  199.8  200.2  198.6  198.7  35831000.0
# 2024-12-17  199.0  200.5  198.8  199.1  52179300.0
# 2024-12-18  198.0  198.7  197.3  197.3  38031000.0
# 2024-12-19  196.5  197.9  195.7  197.4  59741300.0
# 2024-12-20  197.0  198.3  196.3  196.6  72379900.0
# 2024-12-23  197.8  198.5  196.9  197.9  43214000.0
# 2024-12-24  197.9  198.4  197.2  197.3  34660600.0
# 2024-12-25  197.0  197.3  195.0  196.1  43048500.0

# %%
# I don't like this function
def get_stock_data(code):
    df = pdr.DataReader(f'{code}.JP', "stooq").sort_index()
    return df

df = get_stock_data(9434)
display(df)

df_close = df['Close']
df_close.plot()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2019-12-30  1212.34  1225.68  1211.08  1218.17  7.680246e+06
# 2020-01-06  1217.75  1221.09  1206.89  1208.57  9.771190e+06
# 2020-01-07  1211.08  1221.51  1211.08  1217.32  7.532280e+06
# 2020-01-08  1211.90  1213.99  1199.81  1208.57  1.091443e+07
# 2020-01-09  1225.26  1225.68  1217.75  1225.26  8.830074e+06
# ...             ...      ...      ...      ...           ...
# 2024-12-19   196.50   197.90   195.70   197.40  5.974130e+07
# 2024-12-20   197.00   198.30   196.30   196.60  7.237990e+07
# 2024-12-23   197.80   198.50   196.90   197.90  4.321400e+07
# 2024-12-24   197.90   198.40   197.20   197.30  3.466060e+07
# 2024-12-25   197.00   197.30   195.00   196.10  4.304850e+07
#
# [1218 rows x 5 columns]
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Filter

# %%
import datetime as dt

df[df.index >= dt.datetime(2022,1,1)].head(10)
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2022-01-04  1379.45  1381.34  1369.55  1372.38  1.052197e+07
# 2022-01-05  1377.09  1384.17  1373.79  1379.93  1.347151e+07
# 2022-01-06  1378.51  1399.26  1378.04  1383.23  1.088447e+07
# 2022-01-07  1381.81  1386.99  1368.61  1372.38  1.045378e+07
# 2022-01-11  1372.38  1378.04  1367.20  1367.20  8.744782e+06
# 2022-01-12  1368.61  1377.09  1366.72  1372.85  1.364576e+07
# 2022-01-13  1378.99  1380.87  1365.31  1366.72  1.137763e+07
# 2022-01-14  1364.84  1366.72  1357.76  1364.36  1.152866e+07
# 2022-01-17  1369.08  1374.27  1367.67  1373.79  6.007358e+06
# 2022-01-18  1377.57  1380.87  1370.02  1373.79  6.566806e+06

# %%
df[(df.index >= dt.datetime(2022,1,1)) & (df.index < dt.datetime(2024,9,26))]['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df[dt.datetime(2022,1,1):dt.datetime(2024,9,26)]['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.query('Close >= 1500').tail()
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2024-09-19  1974.0  1994.5  1970.5  1974.0   6792700.0
# 2024-09-20  1983.0  2000.0  1969.0  1981.0  13880100.0
# 2024-09-24  1990.0  1994.5  1975.5  1979.0   6787300.0
# 2024-09-25  1979.0  1979.0  1942.0  1942.0   8420900.0
# 2024-09-26  1951.0  1976.5  1950.5  1976.5  11510800.0

# %%
#df.query('High - Low >= 100')
df[df['High'] - df['Low'] >= 100]
df[df['High'] / df['Low'] >= 1.05]
df.query('High/Low >= 1.05')
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2020-03-13  1160.16  1214.83  1104.23  1190.22  3.135335e+07
# 2020-03-24  1168.50  1186.04  1128.43  1145.98  2.665963e+07
# 2020-03-30  1178.23  1195.43  1136.08  1164.90  1.937312e+07
# 2020-04-06  1118.03  1198.87  1116.74  1192.86  1.476812e+07
# 2020-09-14  1121.46  1124.91  1068.15  1068.15  8.780327e+07
# 2023-10-03  1672.50  1766.00  1658.00  1679.00  1.328250e+07
# 2024-07-08  2041.00  2042.00  1940.00  2025.50  9.534000e+06
# 2024-08-05  1811.50  1860.50  1738.50  1810.50  1.916380e+07
# 2024-08-06  1826.50  1876.50  1764.00  1786.00  1.581030e+07
# 2024-08-07  1812.00  1922.00  1798.00  1870.00  1.659580e+07
